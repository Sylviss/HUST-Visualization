# %%
import pandas as pd

data = pd.read_excel('./data/globalterrorismdb_0522dist.xlsx')

# %%
import numpy as np
import matplotlib.pyplot as plt
import country_converter as coco

import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', None)

# %%
data.rename(columns={'iyear':'year',                    'extended':'is_extended',               'alternative_txt':'attack_tactic',      'attacktype1_txt':'attack_type',
                     'targtype1_txt':'target_type',     'targsubtype1_txt':'target_subcat',     'gname':'te_group',                     'motive':'te_motive',
                     'weaptype1_txt':'weapon_type',     'weapsubtype1_txt':'weapon_subtype',    'nkill':'total_killed',                 'nwound':'total_wounded',
                     'nkillter':'te_killed',            'nwoundte':'te_wounded',                'propvalue':'prorperty_damage',         'hostage_con':'ishostkid',
                     'ransomamt':'ransom_amt',          'ransompaid':'ransom_amt_paid',         'hostkidoutcome_txt':'hostage_outcome'
                    }, inplace=True)

# %%
data.head()
# Out:
#         eventid  year  imonth  iday approxdate  is_extended resolution  \
# 0  197000000001  1970       7     2        NaN            0        NaT
# 1  197000000002  1970       0     0        NaN            0        NaT
# 2  197001000001  1970       1     0        NaN            0        NaT
# 3  197001000002  1970       1     0        NaN            0        NaT
# 4  197001000003  1970       1     0        NaN            0        NaT
#
#    country         country_txt  region                   region_txt provstate  \
# 0       58  Dominican Republic       2  Central America & Caribbean  National
# 1      130              Mexico       1                North America   Federal
# 2      160         Philippines       5               Southeast Asia    Tarlac
# 3       78              Greece       8               Western Europe    Attica
# 4      101               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# 0  Santo Domingo  18.456792  -69.951164          1.0         0      NaN
# 1    Mexico city  19.371887  -99.086624          1.0         0      NaN
# 2        Unknown  15.478598  120.599741          4.0         0      NaN
# 3         Athens  37.997490   23.762728          1.0         0      NaN
# 4        Fukouka  33.580412  130.396361          1.0         0      NaN
#
#   summary  crit1  crit2  crit3  doubtterr  alternative attack_tactic  \
# 0     NaN      1      1      1          0          NaN           NaN
# 1     NaN      1      1      1          0          NaN           NaN
# 2     NaN      1      1      1          0          NaN           NaN
# 3     NaN      1      1      1          0          NaN           NaN
# 4     NaN      1      1      1         -9          NaN           NaN
#
#    multiple  success  suicide  attacktype1                     attack_type  \
# 0       0.0        1        0            1                   Assassination
# 1       0.0        1        0            6     Hostage Taking (Kidnapping)
# 2       0.0        1        0            1                   Assassination
# 3       0.0        1        0            3               Bombing/Explosion
# 4       0.0        1        0            7  Facility/Infrastructure Attack
#
#    attacktype2 attacktype2_txt  attacktype3 attacktype3_txt  targtype1  \
# 0          NaN             NaN          NaN             NaN         14
# 1          NaN             NaN          NaN             NaN          7
# 2          NaN             NaN          NaN             NaN         10
# 3          NaN             NaN          NaN             NaN          7
# 4          NaN             NaN          NaN             NaN          7
#
#                    target_type  targsubtype1  \
# 0  Private Citizens & Property          68.0
# 1      Government (Diplomatic)          45.0
# 2          Journalists & Media          54.0
# 3      Government (Diplomatic)          46.0
# 4      Government (Diplomatic)          46.0
#
#                                        target_subcat  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
#
#                          corp1                  target1  natlty1  \
# 0                          NaN             Julio Guzman     58.0
# 1  Belgian Ambassador Daughter  Nadine Chaval, daughter     21.0
# 2             Voice of America                 Employee    217.0
# 3                          NaN             U.S. Embassy    217.0
# 4                          NaN           U.S. Consulate    217.0
#
#           natlty1_txt  targtype2 targtype2_txt  targsubtype2 targsubtype2_txt  \
# 0  Dominican Republic        NaN           NaN           NaN              NaN
# 1             Belgium        NaN           NaN           NaN              NaN
# 2       United States        NaN           NaN           NaN              NaN
# 3       United States        NaN           NaN           NaN              NaN
# 4       United States        NaN           NaN           NaN              NaN
#
#   corp2 target2  natlty2 natlty2_txt  targtype3 targtype3_txt  targsubtype3  \
# 0   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 1   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 2   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 3   NaN     NaN      NaN         NaN        NaN           NaN           NaN
# 4   NaN     NaN      NaN         NaN        NaN           NaN           NaN
#
#   targsubtype3_txt corp3 target3  natlty3 natlty3_txt  \
# 0              NaN   NaN     NaN      NaN         NaN
# 1              NaN   NaN     NaN      NaN         NaN
# 2              NaN   NaN     NaN      NaN         NaN
# 3              NaN   NaN     NaN      NaN         NaN
# 4              NaN   NaN     NaN      NaN         NaN
#
#                              te_group gsubname gname2 gsubname2 gname3  \
# 0                              MANO-D      NaN    NaN       NaN    NaN
# 1  23rd of September Communist League      NaN    NaN       NaN    NaN
# 2                             Unknown      NaN    NaN       NaN    NaN
# 3                             Unknown      NaN    NaN       NaN    NaN
# 4                             Unknown      NaN    NaN       NaN    NaN
#
#   gsubname3 te_motive  guncertain1  guncertain2  guncertain3  individual  \
# 0       NaN       NaN          0.0          NaN          NaN           0
# 1       NaN       NaN          0.0          NaN          NaN           0
# 2       NaN       NaN          0.0          NaN          NaN           0
# 3       NaN       NaN          0.0          NaN          NaN           0
# 4       NaN       NaN          0.0          NaN          NaN           0
#
#    nperps  nperpcap  claimed  claimmode claimmode_txt  claim2  claimmode2  \
# 0     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 1     7.0       NaN      NaN        NaN           NaN     NaN         NaN
# 2     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 3     NaN       NaN      NaN        NaN           NaN     NaN         NaN
# 4     NaN       NaN      NaN        NaN           NaN     NaN         NaN
#
#   claimmode2_txt  claim3  claimmode3 claimmode3_txt  compclaim  weaptype1  \
# 0            NaN     NaN         NaN            NaN        NaN         13
# 1            NaN     NaN         NaN            NaN        NaN         13
# 2            NaN     NaN         NaN            NaN        NaN         13
# 3            NaN     NaN         NaN            NaN        NaN          6
# 4            NaN     NaN         NaN            NaN        NaN          8
#
#   weapon_type  weapsubtype1          weapon_subtype  weaptype2 weaptype2_txt  \
# 0     Unknown           NaN                     NaN        NaN           NaN
# 1     Unknown           NaN                     NaN        NaN           NaN
# 2     Unknown           NaN                     NaN        NaN           NaN
# 3  Explosives          16.0  Unknown Explosive Type        NaN           NaN
# 4  Incendiary           NaN                     NaN        NaN           NaN
#
#    weapsubtype2 weapsubtype2_txt  weaptype3 weaptype3_txt  weapsubtype3  \
# 0           NaN              NaN        NaN           NaN           NaN
# 1           NaN              NaN        NaN           NaN           NaN
# 2           NaN              NaN        NaN           NaN           NaN
# 3           NaN              NaN        NaN           NaN           NaN
# 4           NaN              NaN        NaN           NaN           NaN
#
#   weapsubtype3_txt  weaptype4 weaptype4_txt  weapsubtype4 weapsubtype4_txt  \
# 0              NaN        NaN           NaN           NaN              NaN
# 1              NaN        NaN           NaN           NaN              NaN
# 2              NaN        NaN           NaN           NaN              NaN
# 3              NaN        NaN           NaN           NaN              NaN
# 4              NaN        NaN           NaN           NaN              NaN
#
#    weapdetail  total_killed  nkillus  te_killed  total_wounded  nwoundus  \
# 0         NaN           1.0      NaN        NaN            0.0       NaN
# 1         NaN           0.0      NaN        NaN            0.0       NaN
# 2         NaN           1.0      NaN        NaN            0.0       NaN
# 3   Explosive           NaN      NaN        NaN            NaN       NaN
# 4  Incendiary           NaN      NaN        NaN            NaN       NaN
#
#    te_wounded  property  propextent propextent_txt  prorperty_damage  \
# 0         NaN         0         NaN            NaN               NaN
# 1         NaN         0         NaN            NaN               NaN
# 2         NaN         0         NaN            NaN               NaN
# 3         NaN         1         NaN            NaN               NaN
# 4         NaN         1         NaN            NaN               NaN
#
#   propcomment  ishostkid  nhostkid  nhostkidus  nhours  ndays divert  \
# 0         NaN        0.0       NaN         NaN     NaN    NaN    NaN
# 1         NaN        1.0       1.0         0.0     NaN    NaN    NaN
# 2         NaN        0.0       NaN         NaN     NaN    NaN    NaN
# 3         NaN        0.0       NaN         NaN     NaN    NaN    NaN
# 4         NaN        0.0       NaN         NaN     NaN    NaN    NaN
#
#   kidhijcountry  ransom  ransom_amt  ransomamtus  ransom_amt_paid  \
# 0           NaN     0.0         NaN          NaN              NaN
# 1        Mexico     1.0    800000.0          NaN              NaN
# 2           NaN     0.0         NaN          NaN              NaN
# 3           NaN     0.0         NaN          NaN              NaN
# 4           NaN     0.0         NaN          NaN              NaN
#
#    ransompaidus ransomnote  hostkidoutcome hostage_outcome  nreleased  \
# 0           NaN        NaN             NaN             NaN        NaN
# 1           NaN        NaN             NaN             NaN        NaN
# 2           NaN        NaN             NaN             NaN        NaN
# 3           NaN        NaN             NaN             NaN        NaN
# 4           NaN        NaN             NaN             NaN        NaN
#
#   addnotes scite1 scite2 scite3 dbsource  INT_LOG  INT_IDEO  INT_MISC  \
# 0      NaN    NaN    NaN    NaN     PGIS        0         0         0
# 1      NaN    NaN    NaN    NaN     PGIS        0         1         1
# 2      NaN    NaN    NaN    NaN     PGIS       -9        -9         1
# 3      NaN    NaN    NaN    NaN     PGIS       -9        -9         1
# 4      NaN    NaN    NaN    NaN     PGIS       -9        -9         1
#
#    INT_ANY related
# 0        0     NaN
# 1        1     NaN
# 2        1     NaN
# 3        1     NaN
# 4        1     NaN

# %%
cleaned_data = data[['year',            'is_extended',      'city',         'country_txt',      'region_txt',       'summary',          'success',      'attack_tactic',
                     'attack_type',     'suicide',          'target_type',  'target_subcat',    'te_group',         'te_motive',        'weapon_type',  'weapon_subtype',
                     'total_killed',    'total_wounded',    'te_killed',    'te_wounded',       'prorperty_damage', 'ishostkid',        'ransom',       'ransom_amt',
                     'ransom_amt_paid', 'hostage_outcome']].reset_index(drop=True)

# %%
cleaned_data.head(10)
# Out:
#    year  is_extended           city         country_txt  \
# 0  1970            0  Santo Domingo  Dominican Republic
# 1  1970            0    Mexico city              Mexico
# 2  1970            0        Unknown         Philippines
# 3  1970            0         Athens              Greece
# 4  1970            0        Fukouka               Japan
# 5  1970            0          Cairo       United States
# 6  1970            0     Montevideo             Uruguay
# 7  1970            0        Oakland       United States
# 8  1970            0        Madison       United States
# 9  1970            0        Madison       United States
#
#                     region_txt  \
# 0  Central America & Caribbean
# 1                North America
# 2               Southeast Asia
# 3               Western Europe
# 4                    East Asia
# 5                North America
# 6                South America
# 7                North America
# 8                North America
# 9                North America
#
#                                              summary  success  \
# 0                                            Unknown        1
# 1                                            Unknown        1
# 2                                            Unknown        1
# 3                                            Unknown        1
# 4                                            Unknown        1
# 5  1/1/1970: Unknown African American assailants ...        1
# 6                                            Unknown        0
# 7  1/2/1970: Unknown perpetrators detonated explo...        1
# 8  1/2/1970: Karl Armstrong, a member of the New ...        1
# 9  1/3/1970: Karl Armstrong, a member of the New ...        1
#
#       attack_tactic                     attack_type  suicide  \
# 0           Unknown                   Assassination        0
# 1           Unknown     Hostage Taking (Kidnapping)        0
# 2           Unknown                   Assassination        0
# 3           Unknown               Bombing/Explosion        0
# 4           Unknown  Facility/Infrastructure Attack        0
# 5           Unknown                   Armed Assault        0
# 6           Unknown                   Assassination        0
# 7  Other Crime Type               Bombing/Explosion        0
# 8           Unknown  Facility/Infrastructure Attack        0
# 9           Unknown  Facility/Infrastructure Attack        0
#
#                    target_type  \
# 0  Private Citizens & Property
# 1      Government (Diplomatic)
# 2          Journalists & Media
# 3      Government (Diplomatic)
# 4      Government (Diplomatic)
# 5                       Police
# 6                       Police
# 7                    Utilities
# 8                     Military
# 9         Government (General)
#
#                                        target_subcat  \
# 0                                     Named Civilian
# 1  Diplomatic Personnel (outside of embassy, cons...
# 2                    Radio Journalist/Staff/Facility
# 3                                  Embassy/Consulate
# 4                                  Embassy/Consulate
# 5    Police Building (headquarters, station, school)
# 6                    Police Security Forces/Officers
# 7                                        Electricity
# 8                Military Recruiting Station/Academy
# 9                Government Building/Facility/Office
#
#                              te_group  \
# 0                              MANO-D
# 1  23rd of September Communist League
# 2                             Unknown
# 3                             Unknown
# 4                             Unknown
# 5                  Black Nationalists
# 6                 Tupamaros (Uruguay)
# 7                             Unknown
# 8                     New Year's Gang
# 9                     New Year's Gang
#
#                                         te_motive weapon_type  \
# 0                                         Unknown     Unknown
# 1                                         Unknown     Unknown
# 2                                         Unknown     Unknown
# 3                                         Unknown  Explosives
# 4                                         Unknown  Incendiary
# 5  To protest the Cairo Illinois Police Deparment    Firearms
# 6                                         Unknown    Firearms
# 7                                         Unknown  Explosives
# 8     To protest the War in Vietnam and the draft  Incendiary
# 9     To protest the War in Vietnam and the draft  Incendiary
#
#                       weapon_subtype  total_killed  total_wounded  te_killed  \
# 0                            Unknown             1              0          0
# 1                            Unknown             0              0          0
# 2                            Unknown             1              0          0
# 3             Unknown Explosive Type             0              0          0
# 4                            Unknown             0              0          0
# 5                   Unknown Gun Type             0              0          0
# 6  Automatic or Semi-Automatic Rifle             0              0          0
# 7             Unknown Explosive Type             0              0          0
# 8       Molotov Cocktail/Petrol Bomb             0              0          0
# 9                Gasoline or Alcohol             0              0          0
#
#    te_wounded  prorperty_damage  ishostkid  ransom  ransom_amt  \
# 0           0                -9          0       0           0
# 1           0                -9          1       1      800000
# 2           0                -9          0       0           0
# 3           0                -9          0       0           0
# 4           0                -9          0       0           0
# 5           0                -9          0       0           0
# 6           0                -9          0       0           0
# 7           0             22500          0       0           0
# 8           0             60000          0       0           0
# 9           0                -9          0       0           0
#
#    ransom_amt_paid hostage_outcome  civ_killed  civ_wounded  total_casualties
# 0                0         Unknown           1            0                 1
# 1                0         Unknown           0            0                 0
# 2                0         Unknown           1            0                 1
# 3                0         Unknown           0            0                 0
# 4                0         Unknown           0            0                 0
# 5                0         Unknown           0            0                 0
# 6                0         Unknown           0            0                 0
# 7                0         Unknown           0            0                 0
# 8                0         Unknown           0            0                 0
# 9                0         Unknown           0            0                 0

# %%
cleaned_data.isnull().sum()
# Out:
# year                0
# is_extended         0
# city                0
# country_txt         0
# region_txt          0
# summary             0
# success             0
# attack_tactic       0
# attack_type         0
# suicide             0
# target_type         0
# target_subcat       0
# te_group            0
# te_motive           0
# weapon_type         0
# weapon_subtype      0
# total_killed        0
# total_wounded       0
# te_killed           0
# te_wounded          0
# prorperty_damage    0
# ishostkid           0
# ransom              0
# ransom_amt          0
# ransom_amt_paid     0
# hostage_outcome     0
# civ_killed          0
# civ_wounded         0
# total_casualties    0
# dtype: int64

# %%
cleaned_data['city'].fillna('Unknown', inplace=True)

cleaned_data['summary'].fillna('Unknown', inplace=True)

cleaned_data['attack_tactic'].fillna('Unknown', inplace=True)

cleaned_data['target_subcat'].fillna('Unknown', inplace=True)

cleaned_data['te_motive'].fillna('Unknown', inplace=True)

cleaned_data['weapon_subtype'].fillna('Unknown', inplace=True)



cleaned_data['total_killed'] = cleaned_data['total_killed'].fillna(cleaned_data['total_killed'].mode()[0])

cleaned_data['total_wounded'] = cleaned_data['total_wounded'].fillna(cleaned_data['total_wounded'].mode()[0])

cleaned_data['te_killed'] = cleaned_data['te_killed'].fillna(cleaned_data['te_killed'].mode()[0])

cleaned_data['te_wounded'] = cleaned_data['te_wounded'].fillna(cleaned_data['te_wounded'].mode()[0])


cleaned_data = cleaned_data.astype({'total_killed':'int', 'total_wounded':'int', 'te_killed':'int', 'te_wounded':'int'})


cleaned_data['civ_killed'] = cleaned_data['total_killed'] - cleaned_data['te_killed']

cleaned_data['civ_wounded'] = cleaned_data['total_wounded'] - cleaned_data['te_wounded']

cleaned_data['total_casualties'] = cleaned_data['total_killed'] + cleaned_data['total_wounded']



cleaned_data['prorperty_damage'].fillna(-99.0, inplace=True)
cleaned_data['prorperty_damage'] = cleaned_data['prorperty_damage'].map(lambda x: -9.0 if x < 0 else x)

cleaned_data['ishostkid'].fillna(-9.0, inplace=True)
cleaned_data['ishostkid'] = cleaned_data['ishostkid'].map(lambda x: -9.0 if x < 0 else x)

cleaned_data['ransom'].fillna(-9.0, inplace=True)
cleaned_data['ransom'] = cleaned_data['ransom'].map(lambda x: -9.0 if x < 0 else x)

cleaned_data['ransom_amt'].fillna(0, inplace = True)
cleaned_data['ransom_amt'] = cleaned_data['ransom_amt'].map(lambda x: -9.0 if x < 0 else x)

cleaned_data['ransom_amt_paid'].fillna(0, inplace = True)
cleaned_data['ransom_amt_paid'] = cleaned_data['ransom_amt_paid'].map(lambda x: -9.0 if x < 0 else x)

cleaned_data = cleaned_data.astype({'ransom_amt':'int', 'ransom_amt_paid':'int', 'ishostkid':'int', 'ransom':'int', 'prorperty_damage':'int'})

cleaned_data['hostage_outcome'].fillna('Unknown', inplace=True)

cleaned_data = cleaned_data.astype({'year':'int', 'is_extended':'int', 'success':'int', 'suicide':'int'})

# %%
cleaned_data['weapon_type'] = cleaned_data['weapon_type'].replace({'Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)':'Vehicle'})

cleaned_data['attack_type'] = cleaned_data['attack_type'].replace({'Hostage Taking (Kidnapping)':'Kidnapping','Hostage Taking (Barricade Incident)':'Barricade Incident'})

# %%
cleaned_data['country_txt'] = cleaned_data['country_txt'].replace({
    'East Germany (GDR)':'Germany',
    'West Germany (FRG)':'Germany',
    "People's Republic of the Congo":'Republic of the Congo',
    'Yugoslavia':'Serbia',
    'Serbia-Montenegro':'Serbia',


    'Zaire':'Democratic Republic of the Congo',
    'Czechoslovakia':'Czech Republic',
    'New Hebrides':'Vanuatu',
    'North Yemen':'Yemen',
    'South Yemen':'Yemen',
    'Rhodesia':'Zimbabwe'
})

# %%
custom_map = {
    'Soviet Union': "SUN",
    'International': None
}

cleaned_data['country_txt_clean'] = coco.convert(names=cleaned_data['country_txt'], to='ISO3', not_found=None)

cleaned_data.rename(columns = {'country_txt_clean':'country_code'}, inplace = True)

cleaned_data["country_code"] = cleaned_data["country_code"].replace(custom_map)
# Out:
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# Soviet Union not found in regex
# International not found in regex

# %%
cleaned_data[cleaned_data["country_txt"]=="Vietnam"]
# Out:
#         year  is_extended              city country_txt      region_txt  \
# 52817   1992            0  Ho Chi Minh City     Vietnam  Southeast Asia
# 57510   1994            0  Ho Chi Minh City     Vietnam  Southeast Asia
# 60870   1995            0             Dalat     Vietnam  Southeast Asia
# 62982   1996            0             Hanoi     Vietnam  Southeast Asia
# 65046   1997            0           Unknown     Vietnam  Southeast Asia
# 65525   1997            0  Ho Chi Minh City     Vietnam  Southeast Asia
# 71869   2001            0           Unknown     Vietnam  Southeast Asia
# 71893   2001            0           Unknown     Vietnam  Southeast Asia
# 71936   2001            0           Unknown     Vietnam  Southeast Asia
# 72015   2001            0           Unknown     Vietnam  Southeast Asia
# 174697  2017            0          Bien Hoa     Vietnam  Southeast Asia
# 175120  2017            0  Ho Chi Minh City     Vietnam  Southeast Asia
# 187690  2018            0  Ho Chi Minh City     Vietnam  Southeast Asia
#
#                                                   summary  success  \
# 52817                                             Unknown        1
# 57510                                             Unknown        1
# 60870                                             Unknown        1
# 62982                                             Unknown        1
# 65046                                             Unknown        1
# 65525                                             Unknown        1
# 71869   02/10/2001: Unknown assailants attacked the Cu...        0
# 71893   02/14/2001: Unknown assailants attacked the Cu...        0
# 71936   02/23/2001: Unknown assailants attacked the Cu...        0
# 72015   03/10/2001: Unknown assailants attacked the Cu...        0
# 174697  04/08/2017: Assailants threw two incendiary de...        1
# 175120  04/22/2017: Assailants planted two incendiary ...        0
# 187690  06/20/2018: Two assailants threw two explosive...        1
#
#        attack_tactic                     attack_type  suicide  \
# 52817        Unknown                       Hijacking        0
# 57510        Unknown               Bombing/Explosion        0
# 60870        Unknown               Bombing/Explosion        0
# 62982        Unknown                         Unknown        0
# 65046        Unknown                   Armed Assault        0
# 65525        Unknown                   Assassination        0
# 71869        Unknown                 Unarmed Assault        0
# 71893        Unknown                 Unarmed Assault        0
# 71936        Unknown                 Unarmed Assault        0
# 72015        Unknown                 Unarmed Assault        0
# 174697       Unknown  Facility/Infrastructure Attack        0
# 175120       Unknown  Facility/Infrastructure Attack        0
# 187690       Unknown               Bombing/Explosion        0
#
#                     target_type  \
# 52817       Airports & Aircraft
# 57510                  Business
# 60870      Food or Water Supply
# 62982   Government (Diplomatic)
# 65046                  Maritime
# 65525                  Business
# 71869   Educational Institution
# 71893   Educational Institution
# 71936   Educational Institution
# 72015   Educational Institution
# 174697                   Police
# 175120      Airports & Aircraft
# 187690                   Police
#
#                                             target_subcat  \
# 52817                        Aircraft (not at an airport)
# 57510                                       Bank/Commerce
# 60870                                        Water Supply
# 62982   Diplomatic Personnel (outside of embassy, cons...
# 65046                                 Commercial Maritime
# 65525                                             Unknown
# 71869              School/University/Educational Building
# 71893              School/University/Educational Building
# 71936              School/University/Educational Building
# 72015              School/University/Educational Building
# 174697    Police Building (headquarters, station, school)
# 175120                                            Airport
# 187690    Police Building (headquarters, station, school)
#
#                                           te_group  \
# 52817                                      Unknown
# 57510                                      Unknown
# 60870                                      Unknown
# 62982                                      Unknown
# 65046                                      Unknown
# 65525                                      Unknown
# 71869                                      Unknown
# 71893                                      Unknown
# 71936                                      Unknown
# 72015                                      Unknown
# 174697  Provisional National Government of Vietnam
# 175120  Provisional National Government of Vietnam
# 187690                              Trieu Dai Viet
#
#                                                 te_motive weapon_type  \
# 52817                                             Unknown       Melee
# 57510                                             Unknown  Explosives
# 60870                                             Unknown  Explosives
# 62982                                             Unknown     Unknown
# 65046                                             Unknown    Firearms
# 65525                                             Unknown       Melee
# 71869   Reportedly to protest against the political an...    Chemical
# 71893   Reportedly to protest against the political an...    Chemical
# 71936   Reportedly to protest against the political an...    Chemical
# 72015   Reportedly to protest against the political an...    Chemical
# 174697                                            Unknown  Incendiary
# 175120                                            Unknown  Incendiary
# 187690                                            Unknown  Explosives
#
#                       weapon_subtype  total_killed  total_wounded  te_killed  \
# 52817    Knife or Other Sharp Object             0              0          0
# 57510                        Grenade             0             21          0
# 60870                    Letter Bomb             0              5          0
# 62982                        Unknown             0              1          0
# 65046               Unknown Gun Type             0              0          0
# 65525    Knife or Other Sharp Object             1              0          0
# 71869                        Unknown             0              0          0
# 71893                        Unknown             0              0          0
# 71936                        Unknown             0              0          0
# 72015                        Unknown             0              0          0
# 174697  Molotov Cocktail/Petrol Bomb             0              0          0
# 175120  Molotov Cocktail/Petrol Bomb             0              0          0
# 187690                Remote Trigger             0              1          0
#
#         te_wounded  prorperty_damage  ishostkid  ransom  ransom_amt  \
# 52817            0                -9          1       0           0
# 57510            0                -9          0       0           0
# 60870            0                -9          0       0           0
# 62982            0                -9          0       0           0
# 65046            0                -9          0       0           0
# 65525            0                -9          0       0           0
# 71869            0                -9          0       0           0
# 71893            0                -9          0       0           0
# 71936            0                -9          0       0           0
# 72015            0                -9          0       0           0
# 174697           0             53000          0      -9           0
# 175120           0                -9          0      -9           0
# 187690           0                -9          0      -9           0
#
#         ransom_amt_paid                      hostage_outcome  civ_killed  \
# 52817                 0  Hostage(s) released by perpetrators           0
# 57510                 0                              Unknown           0
# 60870                 0                              Unknown           0
# 62982                 0                              Unknown           0
# 65046                 0                              Unknown           0
# 65525                 0                              Unknown           1
# 71869                 0                              Unknown           0
# 71893                 0                              Unknown           0
# 71936                 0                              Unknown           0
# 72015                 0                              Unknown           0
# 174697                0                              Unknown           0
# 175120                0                              Unknown           0
# 187690                0                              Unknown           0
#
#         civ_wounded  total_casualties country_code country_code
# 52817             0                 0          VNM          VNM
# 57510            21                21          VNM          VNM
# 60870             5                 5          VNM          VNM
# 62982             1                 1          VNM          VNM
# 65046             0                 0          VNM          VNM
# 65525             0                 1          VNM          VNM
# 71869             0                 0          VNM          VNM
# 71893             0                 0          VNM          VNM
# 71936             0                 0          VNM          VNM
# 72015             0                 0          VNM          VNM
# 174697            0                 0          VNM          VNM
# 175120            0                 0          VNM          VNM
# 187690            1                 1          VNM          VNM

# %%
cleaned_data = cleaned_data.dropna()

# %%
cleaned_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 209705 entries, 0 to 209705
# Data columns (total 31 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   year              209705 non-null  int32
#  1   is_extended       209705 non-null  int32
#  2   city              209705 non-null  object
#  3   country_txt       209705 non-null  object
#  4   region_txt        209705 non-null  object
#  5   summary           209705 non-null  object
#  6   success           209705 non-null  int32
#  7   attack_tactic     209705 non-null  object
#  8   attack_type       209705 non-null  object
#  9   suicide           209705 non-null  int32
#  10  target_type       209705 non-null  object
#  11  target_subcat     209705 non-null  object
#  12  te_group          209705 non-null  object
#  13  te_motive         209705 non-null  object
#  14  weapon_type       209705 non-null  object
#  15  weapon_subtype    209705 non-null  object
#  16  total_killed      209705 non-null  int32
#  17  total_wounded     209705 non-null  int32
#  18  te_killed         209705 non-null  int32
#  19  te_wounded        209705 non-null  int32
#  20  prorperty_damage  209705 non-null  int32
#  21  ishostkid         209705 non-null  int32
#  22  ransom            209705 non-null  int32
#  23  ransom_amt        209705 non-null  int32
#  24  ransom_amt_paid   209705 non-null  int32
#  25  hostage_outcome   209705 non-null  object
#  26  civ_killed        209705 non-null  int32
#  27  civ_wounded       209705 non-null  int32
#  28  total_casualties  209705 non-null  int32
#  29  country_code      209705 non-null  object
#  30  country_code      209705 non-null  object
# dtypes: int32(16), object(15)
# memory usage: 38.4+ MB

# %%
cleaned_data.to_csv('./data/res.csv', index=False)

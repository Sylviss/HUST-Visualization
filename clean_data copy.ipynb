# %%
import pandas as pd

data = pd.read_csv("./data/res.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
import country_converter as coco

import warnings
warnings.filterwarnings("ignore")

# %%
data
# Out:
#         year  is_extended           city         country_txt  \
# 0       1970            0  Santo Domingo  Dominican Republic
# 1       1970            0    Mexico city              Mexico
# 2       1970            0        Unknown         Philippines
# 3       1970            0         Athens              Greece
# 4       1970            0        Fukouka               Japan
# ...      ...          ...            ...                 ...
# 209700  2020            0          Sabaa               Yemen
# 209701  2020            0   Beit Maghari               Yemen
# 209702  2020            0        Leipzig             Germany
# 209703  2020            0          Kabul         Afghanistan
# 209704  2020            1          Kelbo        Burkina Faso
#
#                          region_txt  \
# 0       Central America & Caribbean
# 1                     North America
# 2                    Southeast Asia
# 3                    Western Europe
# 4                         East Asia
# ...                             ...
# 209700   Middle East & North Africa
# 209701   Middle East & North Africa
# 209702               Western Europe
# 209703                   South Asia
# 209704           Sub-Saharan Africa
#
#                                                   summary  success  \
# 0                                                 Unknown        1
# 1                                                 Unknown        1
# 2                                                 Unknown        1
# 3                                                 Unknown        1
# 4                                                 Unknown        1
# ...                                                   ...      ...
# 209700  12/31/2020: Assailants fired mortar shells tar...        1
# 209701  12/31/2020: Assailants attempted to plant expl...        1
# 209702  12/31/2020: Assailants set fire to German Army...        1
# 209703  12/31/2020: Assailants shot and killed a civil...        1
# 209704  12/31/2020: Assailants attacked a Volunteers o...        1
#
#                      attack_tactic                     attack_type  suicide  \
# 0                          Unknown                   Assassination        0
# 1                          Unknown                      Kidnapping        0
# 2                          Unknown                   Assassination        0
# 3                          Unknown               Bombing/Explosion        0
# 4                          Unknown  Facility/Infrastructure Attack        0
# ...                            ...                             ...      ...
# 209700                     Unknown               Bombing/Explosion        0
# 209701                     Unknown               Bombing/Explosion        0
# 209702  Insurgency/Guerilla Action  Facility/Infrastructure Attack        0
# 209703                     Unknown                   Armed Assault        0
# 209704  Insurgency/Guerilla Action                   Armed Assault        0
#
#         ... prorperty_damage ishostkid ransom ransom_amt ransom_amt_paid  \
# 0       ...               -9         0      0          0               0
# 1       ...               -9         1      1     800000               0
# 2       ...               -9         0      0          0               0
# 3       ...               -9         0      0          0               0
# 4       ...               -9         0      0          0               0
# ...     ...              ...       ...    ...        ...             ...
# 209700  ...               -9         0     -9          0               0
# 209701  ...               -9         0     -9          0               0
# 209702  ...               -9         0     -9          0               0
# 209703  ...               -9         0     -9          0               0
# 209704  ...               -9        -9     -9          0               0
#
#        hostage_outcome  civ_killed  civ_wounded  total_casualties  \
# 0              Unknown           1            0                 1
# 1              Unknown           0            0                 0
# 2              Unknown           1            0                 1
# 3              Unknown           0            0                 0
# 4              Unknown           0            0                 0
# ...                ...         ...          ...               ...
# 209700         Unknown           0            0                 0
# 209701         Unknown           0            0                 0
# 209702         Unknown           0            0                 0
# 209703         Unknown           1            0                 1
# 209704         Unknown           5            0                 5
#
#         country_code
# 0                DOM
# 1                MEX
# 2                PHL
# 3                GRC
# 4                JPN
# ...              ...
# 209700           YEM
# 209701           YEM
# 209702           DEU
# 209703           AFG
# 209704           BFA
#
# [209705 rows x 30 columns]
